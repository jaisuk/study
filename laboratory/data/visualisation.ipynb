# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/broadcast.csv', index_col=0)

# %%
df.plot()

# %%
df.plot(y = 'KBS')

# %%
df.plot(y=['KBS', 'JTBC'])

# %%
df[['KBS', 'JTBC']]
# Out:
#          KBS   JTBC
# 2011  35.951  7.380
# 2012  36.163  7.878
# 2013  31.989  7.810
# 2014  31.210  7.490
# 2015  27.777  7.267
# 2016  27.583  7.727
# 2017  26.890  9.453

# %%
df[['KBS', 'JTBC']].plot()

# %%
df2 = pd.read_csv('../../datasets/sports.csv', index_col = 0)

# %%
df2
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df2.plot()

# %%
df2.plot(kind='bar')

# %%
df2.plot(kind='barh')

# %%
df2.plot(kind='bar', stacked=True)

# %%
df2['Female'].plot(kind='bar')
